# %%
# import the necessary packages
import numpy as np
import argparse
import cv2

# %% [markdown]
# # REAL TIME

# %%
c = 0.2
# confidence parameter

CLASSES = ["background", "aeroplane", "bicycle", "bird", "boat", "bottle", "bus", "car", "cat", "chair", "cow", "diningtable", "dog", "horse", "motorbike", "person", "pottedplant", "sheep", "sofa", "train", "tvmonitor"]
COLORS = np.random.uniform(0, 255, size=(len(CLASSES), 3))

# load our serialized model from disk
print("[INFO] loading model...")
net = cv2.dnn.readNetFromCaffe("MobileNetSSD_deploy.prototxt.txt", "MobileNetSSD_deploy.caffemodel")
    
cap = cv2.VideoCapture(0)
while (True):
    ret, image = cap.read()
    # load the input image and construct an input blob for the image
    # by resizing to a fixed 300x300 pixels and then normalizing it
    # (note: normalization is done via the authors of the MobileNet SSD
    # implementation)
    (h, w) = image.shape[:2]
    blob = cv2.dnn.blobFromImage(cv2.resize(image, (300, 300)), 0.007843, (300, 300), 127.5)


    # pass the blob through the network and obtain the detections and
    # predictions
    print("[INFO] computing object detections...")
    net.setInput(blob)
    detections = net.forward()


    # loop over the detections
    for i in np.arange(0, detections.shape[2]):
        # extract the confidence (i.e., probability) associated with the
        # prediction
        confidence = detections[0, 0, i, 2]
        # filter out weak detections by ensuring the `confidence` is
        # greater than the minimum confidence
        if confidence > c:
            # extract the index of the class label from the `detections`,
            # then compute the (x, y)-coordinates of the bounding box for
            # the object
            idx = int(detections[0, 0, i, 1])
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            # display the prediction
            label = "{}: {:.2f}%".format(CLASSES[idx], confidence * 100)
            print("[INFO] {}".format(label))
            cv2.rectangle(image, (startX, startY), (endX, endY),
                COLORS[idx], 2)
            y = startY - 15 if startY - 15 > 15 else startY + 15
            cv2.putText(image, label, (startX, y),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLORS[idx], 2)
    
    
    cv2.imshow("Output", image)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [INFO] loading model...
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 99.93%
# [INFO] computing object detections...
# [INFO] person: 98.76%
# [INFO] computing object detections...
# [INFO] person: 98.16%
# [INFO] computing object detections...
# [INFO] person: 99.03%
# [INFO] computing object detections...
# [INFO] person: 99.02%
# [INFO] computing object detections...
# [INFO] person: 98.86%
# [INFO] computing object detections...
# [INFO] person: 98.15%
# [INFO] computing object detections...
# [INFO] person: 98.36%
# [INFO] computing object detections...
# [INFO] person: 98.48%
# [INFO] computing object detections...
# [INFO] person: 98.57%
# [INFO] computing object detections...
# [INFO] person: 98.66%
# [INFO] computing object detections...
# [INFO] person: 98.62%
# [INFO] computing object detections...
# [INFO] person: 97.21%
# [INFO] computing object detections...
# [INFO] person: 99.08%
# [INFO] computing object detections...
# [INFO] person: 99.15%
# [INFO] computing object detections...
# [INFO] person: 99.08%
# [INFO] computing object detections...
# [INFO] person: 99.22%
# [INFO] computing object detections...
# [INFO] chair: 57.43%
# [INFO] person: 97.92%
# [INFO] computing object detections...
# [INFO] person: 98.43%
# [INFO] computing object detections...
# [INFO] chair: 68.32%
# [INFO] person: 97.83%
# [INFO] computing object detections...
# [INFO] chair: 73.66%
# [INFO] person: 98.01%
# [INFO] computing object detections...
# [INFO] chair: 59.92%
# [INFO] person: 97.04%
# [INFO] computing object detections...
# [INFO] chair: 62.17%
# [INFO] person: 98.12%
# [INFO] computing object detections...
# [INFO] chair: 70.44%
# [INFO] person: 98.20%
# [INFO] computing object detections...
# [INFO] chair: 53.45%
# [INFO] person: 98.80%
# [INFO] computing object detections...
# [INFO] chair: 40.82%
# [INFO] person: 98.85%
# [INFO] computing object detections...
# [INFO] person: 98.90%
# [INFO] computing object detections...
# [INFO] chair: 66.18%
# [INFO] person: 97.92%
# [INFO] computing object detections...
# [INFO] chair: 70.94%
# [INFO] person: 98.22%
# [INFO] computing object detections...
# [INFO] chair: 61.09%
# [INFO] person: 98.10%
# [INFO] computing object detections...
# [INFO] chair: 64.02%
# [INFO] person: 98.56%
# [INFO] computing object detections...
# [INFO] chair: 56.67%
# [INFO] person: 99.03%
# [INFO] computing object detections...
# [INFO] chair: 60.93%
# [INFO] person: 99.22%
# [INFO] computing object detections...
# [INFO] chair: 70.16%
# [INFO] person: 98.20%
# [INFO] computing object detections...
# [INFO] chair: 62.89%
# [INFO] person: 96.88%
# [INFO] computing object detections...
# [INFO] chair: 50.53%
# [INFO] person: 96.27%
# [INFO] computing object detections...
# [INFO] chair: 51.02%
# [INFO] person: 98.22%
# [INFO] computing object detections...
# [INFO] chair: 53.74%
# [INFO] person: 98.04%
# [INFO] computing object detections...
# [INFO] chair: 70.52%
# [INFO] person: 95.92%
# [INFO] computing object detections...
# [INFO] person: 98.20%
# [INFO] computing object detections...
# [INFO] chair: 61.33%
# [INFO] person: 97.74%
# [INFO] computing object detections...
# [INFO] chair: 71.29%
# [INFO] person: 95.50%
# [INFO] computing object detections...
# [INFO] chair: 71.31%
# [INFO] person: 95.23%
# [INFO] computing object detections...
# [INFO] chair: 44.78%
# [INFO] person: 96.37%
# [INFO] computing object detections...
# [INFO] chair: 60.77%
# [INFO] person: 96.94%
# [INFO] computing object detections...
# [INFO] chair: 60.56%
# [INFO] person: 99.02%
# [INFO] computing object detections...
# [INFO] chair: 58.73%
# [INFO] person: 99.55%
# [INFO] computing object detections...
# [INFO] chair: 61.39%
# [INFO] person: 99.26%
# [INFO] computing object detections...
# [INFO] chair: 62.10%
# [INFO] person: 99.63%
# [INFO] computing object detections...
# [INFO] person: 99.25%
# [INFO] computing object detections...
# [INFO] person: 99.24%
# [INFO] computing object detections...
# [INFO] person: 99.40%
# [INFO] computing object detections...
# [INFO] person: 99.58%
# [INFO] computing object detections...
# [INFO] person: 99.75%
# [INFO] computing object detections...
# [INFO] person: 99.63%
# [INFO] computing object detections...
# [INFO] person: 99.76%
# [INFO] computing object detections...
# [INFO] person: 99.69%
# [INFO] computing object detections...
# [INFO] person: 99.55%
# [INFO] computing object detections...
# [INFO] chair: 41.20%
# [INFO] person: 99.46%
# [INFO] computing object detections...
# [INFO] person: 99.95%
# [INFO] computing object detections...
# [INFO] person: 99.62%
# [INFO] computing object detections...
# [INFO] person: 99.81%
# [INFO] computing object detections...
# [INFO] person: 98.78%
# [INFO] computing object detections...
# [INFO] person: 99.18%
# [INFO] computing object detections...
# [INFO] person: 97.64%
# [INFO] computing object detections...
# [INFO] person: 98.49%
# [INFO] computing object detections...
# [INFO] person: 98.74%
# [INFO] computing object detections...
# [INFO] person: 98.71%
# [INFO] computing object detections...
# [INFO] person: 99.41%
# [INFO] computing object detections...
# [INFO] person: 98.84%
# [INFO] computing object detections...
# [INFO] computing object detections...
# [INFO] chair: 75.64%
# [INFO] person: 96.35%
# [INFO] computing object detections...
# [INFO] chair: 63.14%
# [INFO] person: 96.50%
# [INFO] computing object detections...
# [INFO] chair: 60.56%
# [INFO] person: 96.64%
# [INFO] computing object detections...
# [INFO] person: 95.71%
# [INFO] computing object detections...
# [INFO] chair: 53.49%
# [INFO] person: 95.77%
# [INFO] computing object detections...
# [INFO] chair: 73.75%
# [INFO] person: 96.19%
# [INFO] computing object detections...
# [INFO] chair: 44.30%
# [INFO] person: 96.95%
# [INFO] computing object detections...
# [INFO] chair: 44.21%
# [INFO] person: 97.70%
# [INFO] computing object detections...
# [INFO] chair: 62.41%
# [INFO] person: 97.37%
# [INFO] computing object detections...
# [INFO] chair: 64.54%
# [INFO] person: 97.62%
# [INFO] computing object detections...
# [INFO] chair: 59.69%
# [INFO] person: 97.39%
# [INFO] computing object detections...
# [INFO] chair: 77.26%
# [INFO] person: 97.61%
# [INFO] computing object detections...
# [INFO] chair: 51.97%
# [INFO] person: 98.50%
# [INFO] computing object detections...
# [INFO] chair: 61.02%
# [INFO] person: 99.26%
# [INFO] computing object detections...
# [INFO] chair: 40.58%
# [INFO] person: 99.09%
# [INFO] computing object detections...
# [INFO] person: 99.10%
# [INFO] computing object detections...
# [INFO] person: 99.14%
# [INFO] computing object detections...
# [INFO] person: 99.41%
# [INFO] computing object detections...
# [INFO] person: 98.87%
# [INFO] computing object detections...
# [INFO] person: 97.48%
# [INFO] computing object detections...
# [INFO] person: 96.20%
# [INFO] computing object detections...
# [INFO] person: 96.35%
# [INFO] computing object detections...
# [INFO] person: 96.05%
# [INFO] computing object detections...
# [INFO] person: 95.46%
# [INFO] computing object detections...
# [INFO] person: 95.93%
# [INFO] computing object detections...
# [INFO] person: 97.45%
# [INFO] computing object detections...
# [INFO] chair: 44.19%
# [INFO] person: 95.83%
# [INFO] computing object detections...
# [INFO] person: 95.39%
# [INFO] computing object detections...
# [INFO] person: 94.05%
# [INFO] computing object detections...
# [INFO] person: 94.55%
# [INFO] computing object detections...
# [INFO] chair: 53.70%
# [INFO] person: 93.65%
# [INFO] computing object detections...
# [INFO] person: 95.11%
# [INFO] computing object detections...
# [INFO] person: 98.10%
# [INFO] computing object detections...
# [INFO] person: 98.96%
# [INFO] computing object detections...
# [INFO] person: 99.62%
# [INFO] computing object detections...
# [INFO] person: 88.03%
# [INFO] computing object detections...
# [INFO] person: 99.09%
# [INFO] computing object detections...
# [INFO] person: 99.46%
# [INFO] computing object detections...
# [INFO] person: 99.94%
# [INFO] computing object detections...
# [INFO] person: 99.76%
# [INFO] computing object detections...
# [INFO] person: 99.97%
# [INFO] computing object detections...
# [INFO] person: 99.96%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 99.83%
# [INFO] computing object detections...
# [INFO] cat: 57.55%
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.93%
# [INFO] computing object detections...
# [INFO] diningtable: 56.52%
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] diningtable: 65.63%
# [INFO] person: 99.89%
# [INFO] computing object detections...
# [INFO] person: 99.40%
# [INFO] computing object detections...
# [INFO] diningtable: 76.82%
# [INFO] person: 99.81%
# [INFO] computing object detections...
# [INFO] diningtable: 50.79%
# [INFO] person: 90.92%
# [INFO] person: 48.69%
# [INFO] computing object detections...
# [INFO] diningtable: 72.80%
# [INFO] person: 67.22%
# [INFO] computing object detections...
# [INFO] diningtable: 69.33%
# [INFO] person: 40.06%
# [INFO] computing object detections...
# [INFO] person: 52.91%
# [INFO] computing object detections...
# [INFO] person: 61.63%
# [INFO] computing object detections...
# [INFO] diningtable: 61.44%
# [INFO] computing object detections...
# [INFO] diningtable: 65.01%
# [INFO] motorbike: 41.14%
# [INFO] computing object detections...
# [INFO] diningtable: 56.58%
# [INFO] motorbike: 42.85%
# [INFO] person: 44.14%
# [INFO] computing object detections...
# [INFO] diningtable: 46.25%
# [INFO] person: 40.46%
# [INFO] computing object detections...
# [INFO] diningtable: 74.93%
# [INFO] motorbike: 45.20%
# [INFO] person: 50.37%
# [INFO] person: 42.12%
# [INFO] computing object detections...
# [INFO] diningtable: 62.93%
# [INFO] person: 69.48%
# [INFO] computing object detections...
# [INFO] diningtable: 71.13%
# [INFO] person: 77.22%
# [INFO] computing object detections...
# [INFO] diningtable: 61.56%
# [INFO] person: 77.99%
# [INFO] person: 45.04%
# [INFO] computing object detections...
# [INFO] diningtable: 54.64%
# [INFO] person: 78.44%
# [INFO] person: 41.85%
# [INFO] computing object detections...
# [INFO] motorbike: 47.73%
# [INFO] person: 72.82%
# [INFO] computing object detections...
# [INFO] diningtable: 69.21%
# [INFO] person: 91.14%
# [INFO] computing object detections...
# [INFO] diningtable: 66.37%
# [INFO] person: 99.79%
# [INFO] computing object detections...
# [INFO] diningtable: 40.46%
# [INFO] person: 99.96%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 99.90%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.97%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.45%
# [INFO] computing object detections...
# [INFO] person: 97.54%
# [INFO] computing object detections...
# [INFO] person: 99.94%
# [INFO] computing object detections...
# [INFO] person: 99.94%
# [INFO] computing object detections...
# [INFO] person: 99.94%
# [INFO] computing object detections...
# [INFO] person: 99.97%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.77%
# [INFO] computing object detections...
# [INFO] bottle: 55.27%
# [INFO] person: 99.96%
# [INFO] computing object detections...
# [INFO] person: 99.64%
# [INFO] computing object detections...
# [INFO] person: 99.89%
# [INFO] computing object detections...
# [INFO] chair: 84.91%
# [INFO] person: 99.47%
# [INFO] computing object detections...
# [INFO] chair: 58.30%
# [INFO] person: 99.91%
# [INFO] computing object detections...
# [INFO] person: 99.88%
# [INFO] computing object detections...
# [INFO] person: 99.93%
# [INFO] computing object detections...
# [INFO] person: 99.24%
# [INFO] computing object detections...
# [INFO] chair: 41.06%
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.97%
# [INFO] sofa: 40.34%
# [INFO] computing object detections...
# [INFO] person: 99.96%
# [INFO] computing object detections...
# [INFO] chair: 53.82%
# [INFO] person: 99.96%
# [INFO] computing object detections...
# [INFO] person: 99.95%
# [INFO] computing object detections...
# [INFO] chair: 59.20%
# [INFO] chair: 41.46%
# [INFO] person: 99.95%
# [INFO] computing object detections...
# [INFO] chair: 59.64%
# [INFO] person: 99.96%
# [INFO] computing object detections...
# [INFO] chair: 54.60%
# [INFO] person: 99.76%
# [INFO] computing object detections...
# [INFO] chair: 73.73%
# [INFO] chair: 45.45%
# [INFO] person: 99.73%
# [INFO] computing object detections...
# [INFO] chair: 75.01%
# [INFO] person: 99.64%
# [INFO] computing object detections...
# [INFO] chair: 69.97%
# [INFO] person: 99.69%
# [INFO] computing object detections...
# [INFO] chair: 77.66%
# [INFO] chair: 40.62%
# [INFO] person: 99.29%
# [INFO] computing object detections...
# [INFO] chair: 81.87%
# [INFO] person: 99.67%
# [INFO] computing object detections...
# [INFO] chair: 86.29%
# [INFO] person: 99.51%
# [INFO] chair: 43.22%
# [INFO] person: 94.64%
# [INFO] computing object detections...
# [INFO] person: 88.57%
# [INFO] computing object detections...
# [INFO] person: 90.16%
# [INFO] computing object detections...
# [INFO] chair: 41.85%
# [INFO] person: 97.00%
# [INFO] computing object detections...
# [INFO] chair: 68.35%
# [INFO] person: 99.71%
# [INFO] computing object detections...
# [INFO] chair: 57.29%
# [INFO] person: 99.82%
# [INFO] computing object detections...
# [INFO] bottle: 44.14%
# [INFO] chair: 50.95%
# [INFO] chair: 43.27%
# [INFO] person: 99.95%
# [INFO] computing object detections...
# [INFO] chair: 47.64%
# [INFO] chair: 41.60%
# [INFO] person: 99.96%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] sofa: 50.93%
# [INFO] computing object detections...
# [INFO] person: 99.96%
# [INFO] computing object detections...
# [INFO] person: 99.95%
# [INFO] computing object detections...
# [INFO] person: 99.95%
# [INFO] computing object detections...
# [INFO] person: 99.92%
# [INFO] computing object detections...
# [INFO] person: 99.94%
# [INFO] computing object detections...
# [INFO] bottle: 60.03%
# [INFO] person: 99.96%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.87%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] bottle: 42.53%
# [INFO] person: 99.97%
# [INFO] computing object detections...
# [INFO] person: 99.95%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.83%
# [INFO] computing object detections...
# [INFO] person: 99.93%
# [INFO] computing object detections...
# [INFO] person: 99.96%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 100.00%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.99%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.97%
# [INFO] computing object detections...
# [INFO] person: 99.98%
# [INFO] computing object detections...
# [INFO] person: 99.98%

# %% [markdown]
# # TESTING

# %%
# initialize the list of class labels MobileNet SSD was trained to
# detect, then generate a set of bounding box colors for each class
CLASSES = ["background", "aeroplane", "bicycle", "bird", "boat", "bottle", "bus", "car", "cat", "chair", "cow", "diningtable", "dog", "horse", "motorbike", "person", "pottedplant", "sheep", "sofa", "train", "tvmonitor"]
COLORS = np.random.uniform(0, 255, size=(len(CLASSES), 3))

# %%
# load our serialized model from disk
print("[INFO] loading model...")
net = cv2.dnn.readNetFromCaffe("MobileNetSSD_deploy.prototxt.txt", "MobileNetSSD_deploy.caffemodel")
# Out:
# [INFO] loading model...

# %%
# load the input image and construct an input blob for the image
# by resizing to a fixed 300x300 pixels and then normalizing it
# (note: normalization is done via the authors of the MobileNet SSD
# implementation)
image = cv2.imread("../images/dog.jpg")
(h, w) = image.shape[:2]
blob = cv2.dnn.blobFromImage(cv2.resize(image, (300, 300)), 0.007843, (300, 300), 127.5)

# %%
# pass the blob through the network and obtain the detections and
# predictions
print("[INFO] computing object detections...")
net.setInput(blob)
detections = net.forward()
# Out:
# [INFO] computing object detections...

# %%
# loop over the detections
for i in np.arange(0, detections.shape[2]):
    # extract the confidence (i.e., probability) associated with the
    # prediction
    confidence = detections[0, 0, i, 2]
    # filter out weak detections by ensuring the `confidence` is
    # greater than the minimum confidence
    if confidence > 0.2:
        # extract the index of the class label from the `detections`,
        # then compute the (x, y)-coordinates of the bounding box for
        # the object
        idx = int(detections[0, 0, i, 1])
        box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
        (startX, startY, endX, endY) = box.astype("int")
        # display the prediction
        label = "{}: {:.2f}%".format(CLASSES[idx], confidence * 100)
        print("[INFO] {}".format(label))
        cv2.rectangle(image, (startX, startY), (endX, endY),
            COLORS[idx], 2)
        y = startY - 15 if startY - 15 > 15 else startY + 15
        cv2.putText(image, label, (startX, y),
            cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLORS[idx], 2)
# Out:
# [INFO] bicycle: 99.79%
# [INFO] car: 99.36%
# [INFO] dog: 96.36%

# %%
cv2.imshow("Output", image)
cv2.waitKey(0)
# Out:
# 9
